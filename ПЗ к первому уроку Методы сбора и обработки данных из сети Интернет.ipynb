# %%
import requests
from pprint import pprint
import json

# %% [markdown]
# ### 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
username = 'Eugenyvarlamov'
password = 'xxxx'
req = requests.get('https://api.github.com/user/repos', auth=(username, password))

# %%
data = json.loads(req.text)
for i, repos in enumerate(data):
    print(i+1, data[i]['full_name'], data[i]['html_url'])
    
f = open('github_repos.json', 'w+')
f.write(req.text)
f.close()
# Out:
# 1 Eugenyvarlamov/Data-Bases https://github.com/Eugenyvarlamov/Data-Bases
# 2 Eugenyvarlamov/Methods-of-data-collection-and-processing-from-the-Internet https://github.com/Eugenyvarlamov/Methods-of-data-collection-and-processing-from-the-Internet
# 3 Eugenyvarlamov/Python-for-Data-Science https://github.com/Eugenyvarlamov/Python-for-Data-Science

# %% [markdown]
# ### 2. Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию через curl, Postman, Python.Ответ сервера записать в файл (приложить скриншот для Postman и curl)

# %%
METHOD_NAME = 'friends.get'
PARAMETERS = 'user_id=181766467&order=name&fields=nickname,sex,online'
ACCESS_TOKEN = '4d28214531a0743777de17961b6c0375991578f360f0e6e4aef81581fe708e842d724d9de846f5058bf76'
V = '5.92'
url = 'https://api.vk.com/method/{METHOD_NAME}?\
{PARAMETERS}&access_token={ACCESS_TOKEN}&v={V}'.format(METHOD_NAME = METHOD_NAME, 
                                                       PARAMETERS = PARAMETERS, 
                                                       ACCESS_TOKEN = ACCESS_TOKEN, V = V)

# %%
req_vk = requests.get(url)

# %%
data_vk = json.loads(req_vk.text)
pprint(data_vk)
# Out:
# {'response': {'count': 299,
#               'items': [{'can_access_closed': True,
#                          'first_name': 'Alexandr',
#                          'id': 20898576,
#                          'is_closed': False,
#                          'last_name': 'Shumilin',
#                          'nickname': '',
#                          'online': 0,
#                          'sex': 2,
#                          'track_code': 'ff7de3aff93Ox-udQ51Et1w4ljnT7DtFIZhoBkq7AxF6sgvGtfwStp2h25x1wBCmN9Jb'},
#                         {'can_access_closed': True,
#                          'first_name': 'Alexey',
#                          'id': 8618428,
#                          'is_closed': False,
#                          'last_name': 'Andreew',
#                          'nickname': '',
#                          'online': 0,
#                          'sex': 2,
#                          'track_code': '99953cc15Q2FqDnLx119s_NGEAPZrussUWmMYB9K_3V8o-MieXWIZoiaAcyiVir0mazd'},
# ...

# %%
f_vk = open('friends_list.json', 'w+', encoding = 'utf-8')
f_vk.write(req_vk.text)
f_vk.close()
